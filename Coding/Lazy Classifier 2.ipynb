# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import accuracy_score

# %%
df=pd.read_csv('Hotel Reservations.csv')

# %%
df
# Out:
#       Booking_ID  no_of_adults  no_of_children  no_of_weekend_nights  \
# 0       INN00001             2               0                     1
# 1       INN00002             2               0                     2
# 2       INN00003             1               0                     2
# 3       INN00004             2               0                     0
# 4       INN00005             2               0                     1
# ...          ...           ...             ...                   ...
# 36270   INN36271             3               0                     2
# 36271   INN36272             2               0                     1
# 36272   INN36273             2               0                     2
# 36273   INN36274             2               0                     0
# 36274   INN36275             2               0                     1
#
#        no_of_week_nights type_of_meal_plan  required_car_parking_space  \
# ...

# %%
data=df[['no_of_adults','no_of_children', 'no_of_weekend_nights', 'no_of_week_nights','lead_time' ,'arrival_month', 'arrival_date', 'market_segment_type', 'no_of_previous_cancellations', 'no_of_previous_bookings_not_canceled','avg_price_per_room']]
data
# Out:
#        no_of_adults  no_of_children  no_of_weekend_nights  no_of_week_nights  \
# 0                 2               0                     1                  2
# 1                 2               0                     2                  3
# 2                 1               0                     2                  1
# 3                 2               0                     0                  2
# 4                 2               0                     1                  1
# ...             ...             ...                   ...                ...
# 36270             3               0                     2                  6
# 36271             2               0                     1                  3
# 36272             2               0                     2                  6
# 36273             2               0                     0                  3
# 36274             2               0                     1                  2
#
# ...

# %%
from sklearn.preprocessing import LabelEncoder

# One-hot encode the categorical features
data = pd.get_dummies(data, columns=['market_segment_type'])

# %%
data
# Out:
#        no_of_adults  no_of_children  no_of_weekend_nights  no_of_week_nights  \
# 0                 2               0                     1                  2
# 1                 2               0                     2                  3
# 2                 1               0                     2                  1
# 3                 2               0                     0                  2
# 4                 2               0                     1                  1
# ...             ...             ...                   ...                ...
# 36270             3               0                     2                  6
# 36271             2               0                     1                  3
# 36272             2               0                     2                  6
# 36273             2               0                     0                  3
# 36274             2               0                     1                  2
#
# ...

# %%
x=data[['no_of_adults','no_of_children', 'no_of_weekend_nights', 'no_of_week_nights','lead_time', 'no_of_previous_cancellations']]
y=df['booking_status']

# %%
X_train, X_test, y_train, y_test = train_test_split(x, y, test_size=0.3, random_state=42)

# %%
from lazypredict.Supervised import LazyClassifier
clf = LazyClassifier()
models = clf.fit(X_train, X_test, y_train, y_test)
# Out:
# 100%|██████████| 29/29 [02:19<00:00,  4.81s/it]
# [LightGBM] [Info] Number of positive: 17114, number of negative: 8278
# [LightGBM] [Warning] Auto-choosing row-wise multi-threading, the overhead of testing was 0.001138 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 295
# [LightGBM] [Info] Number of data points in the train set: 25392, number of used features: 6
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.673992 -> initscore=0.726295
# [LightGBM] [Info] Start training from score 0.726295

# %%
print(models)
# Out:
# (                               Accuracy  Balanced Accuracy ROC AUC  F1 Score  \
# Model
# RandomForestClassifier             0.78               0.73    None      0.78
# ExtraTreesClassifier               0.77               0.73    None      0.77
# BaggingClassifier                  0.78               0.73    None      0.77
# ExtraTreeClassifier                0.77               0.73    None      0.77
# DecisionTreeClassifier             0.77               0.73    None      0.77
# LGBMClassifier                     0.79               0.72    None      0.78
# KNeighborsClassifier               0.77               0.71    None      0.76
# LabelSpreading                     0.78               0.70    None      0.76
# LabelPropagation                   0.78               0.70    None      0.76
# AdaBoostClassifier                 0.77               0.69    None      0.75
# NuSVC                              0.77               0.69    None      0.75
# ...
